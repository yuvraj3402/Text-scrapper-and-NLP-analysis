# %%
import pandas as pd
df=pd.read_excel("output_folder\output.xlsx")

# %%
df.head()
# Out:
#        URL_ID  POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  \
# 0  bctech2011             144              47        0.507853
# 1  bctech2012              22               6        0.571429
# 2  bctech2013              24              10        0.411765
# 3  bctech2014              15               7        0.363636
# 4  bctech2015              18               3        0.714286
#
#    SUBJECTIVITY SCORE  AVERAGE SENTENCE LENGTH PERCENTAGE OF COMPLEX WORDS  \
# 0            0.073631                       15                      62.6 %
# 1            0.054795                       10                      65.8 %
# 2            0.055195                       18                      61.9 %
# 3            0.045361                        9                      68.7 %
# 4            0.035117                       21                      51.2 %
#
#    FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  \
# 0      31.04                              14.7                1625
# ...
